# %%
import os
import json
import shutil

import session_processing_helper_c5 as helper
import utils_c5 as utils

import pandas as pd

# %% [markdown]
# # Data cleaning

# %% [markdown]
# create a folder with the time period as name (eg. '20250531-20240806')
# <br>
# create a folder named 'raw' and put all session files in 'raw'

# %% [markdown]
# ## Back up raw

# %%
period = '20240123-20240415'
data_dir = '/Users/rebekahzhang/data/behavior_data'

# %%
def backup(source_dir, destination_dir):
    if not os.path.isdir(destination_dir):
        shutil.copytree(source_dir, destination_dir)
        print(f"{os.path.basename(source_dir)} folder backed up")
    else:
        print(f"{os.path.basename(destination_dir)} already exist")

# %%
raw = os.path.join(data_dir, period, "raw")
clean = os.path.join(data_dir, period, "clean")
backup(raw, clean)
# Out:
# raw folder backed up

# %% [markdown]
# ## Check if sessions have both meta and events

# %%
data_folder = os.path.join(data_dir, 'exp2')
print(data_folder)
# Out:
# /Users/rebekahzhang/data/behavior_data/exp2

# %%
def check_session_files(data_folder):
  files_check = []
  for entry in os.scandir(data_folder):
    if entry.is_dir():
      dir = entry.name
      session_path = os.path.join(data_folder, dir)

      events_found = False
      meta_found = False

      required_files = [f.name for f in os.scandir(session_path) if f.is_file() and not f.name.startswith('.')]
      for filename in required_files:
        if filename.startswith("events_"):
          events_found = True
        elif filename.startswith("meta_"):
          meta_found = True

      files_check.append({
          'dir': dir,
          'events': events_found,
          'meta': meta_found
      })

  files_check_df = pd.DataFrame(files_check).sort_values("dir")
  missing_meta = files_check_df[files_check_df.meta==False]
  missing_events = files_check_df[files_check_df.events==False]

  return missing_meta, missing_events

# %%
missing_events, missing_meta = check_session_files(data_folder)
if len(missing_meta) == 0 and len(missing_events) == 0:
    print("no sessions with missing files!")
else:
    print("missing meta")
    display(missing_meta)
    print("missing events")
    display(missing_events)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 missing_events, missing_meta = check_session_files(data_folder)
#       2 if len(missing_meta) == 0 and len(missing_events) == 0:
#       3     print("no sessions with missing files!")
#
# Input In [7], in check_session_files(data_folder)
#       1 def check_session_files(data_folder):
#       2   files_check = []
# ----> 3   for entry in os.scandir(data_folder):
#       4     if entry.is_dir():
#       5       dir = entry.name
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/rebekahzhang/data/behavior_data/exp2'

# %% [markdown]
# ## Generate and save sessions log

# %% [markdown]
# generate session log using meta data from each session and add columns of basic info to each session

# %%
def modify_total_trial(row):
    if row['ending_code'] == 'pygame':
        return row['total_trial'] - 1
    elif row['ending_code'] == 'miss':
        return row['total_trial'] - 5
    else:
        return row['total_trial']

# %%
def modify_sessions_all(sessions_all):
    sessions_all['dir'] = sessions_all['date']+ '_' + sessions_all['time'] + '_' + sessions_all['mouse']
    sessions_all = sessions_all.sort_values('dir')
    sessions_all[['exp', 'group']] = sessions_all['exp'].str.extract(r'exp(\d)_(short|long)')
    sessions_all['group'] = sessions_all['group'].map({'short': 's', 'long': 'l'})
    sessions_all['total_trial'] = sessions_all.apply(modify_total_trial, axis=1)
    sessions_all = sessions_all.drop(['forward_file'], axis=1)
    return sessions_all

# %%
def generate_sessions_all(data_folder):
    """Generates a DataFrame using session metadata from JSON files.
    Args:
        data_folder (str): Path to the directory containing JSON files.
    Returns:
        pd.DataFrame: DataFrame containing session metadata, sorted by 'dir' column.
    """

    data = []
    for root, _, files in os.walk(data_folder):
        for file in files:
            if file.startswith("meta_") and file.endswith(".json"):
                path = os.path.join(root, file)
                try:
                    with open(path) as f:
                        session_data = json.load(f)['session_config']
                        data.append(session_data)
                except Exception as e:
                    print(f"Error processing file {file}: {e}")

    sessions_all = pd.DataFrame(data)
    sessions_all = modify_sessions_all(sessions_all)
    return sessions_all

# %%
def generate_sessions_training(sessions_all):
    sessions_training = sessions_all.loc[sessions_all.training == 'regular'].reset_index()
    sessions_training = sessions_training.groupby('mouse', group_keys=False).apply(helper.assign_session_numbers)
    return sessions_training

# %% [markdown]
# ### re-run after every quality control steps

# %%
sessions_all = generate_sessions_all(data_folder)
sessions_training = generate_sessions_training(sessions_all)

utils.save_as_csv(df=sessions_all, folder=data_folder, filename='sessions_all.csv')
utils.save_as_csv(df=sessions_training, folder=data_folder, filename='sessions_training.csv')

sessions_training
# Out:
# Error processing file meta_2024-04-12_10-23-31_RZ036.json: 'session_config'
# Error processing file meta_2024-04-05_11-21-57_RZ036.json: 'session_config'
# Error processing file meta_2024-01-24_10-14-35_RZ036.json: 'session_config'
# Error processing file meta_2024-04-05_12-01-59_RZ037.json: 'session_config'
# Error processing file meta_2024-03-27_11-12-26_RZ038.json: 'session_config'
# Error processing file meta_2024-02-01_13-11-32_RZ039.json: 'session_config'
# Error processing file meta_2024-03-04_13-25-49_RZ038.json: 'session_config'
# Error processing file meta_2024-04-01_12-46-49_RZ037.json: 'session_config'
# Error processing file meta_2024-02-23_12-20-38_RZ038.json: 'session_config'
# Error processing file meta_2024-03-20_10-07-53_RZ034.json: 'session_config'
# Error processing file meta_2024-02-02_11-37-54_RZ038.json: 'session_config'
# Error processing file meta_2024-03-25_11-32-23_RZ034.json: 'session_config'
# Error processing file meta_2024-01-30_09-52-34_RZ034.json: 'session_config'
# Error processing file meta_2024-02-12_11-52-01_RZ036.json: 'session_config'
# Error processing file meta_2024-03-21_10-14-07_RZ034.json: 'session_config'
# Error processing file meta_2024-04-02_12-22-01_RZ038.json: 'session_config'
# Error processing file meta_2024-01-30_10-59-43_RZ038.json: 'session_config'
# Error processing file meta_2024-03-19_11-33-24_RZ037.json: 'session_config'
# Error processing file meta_2024-02-07_11-55-06_RZ037.json: 'session_config'
# Error processing file meta_2024-02-09_12-55-59_RZ039.json: 'session_config'
# Error processing file meta_2024-02-02_10-33-43_RZ034.json: 'session_config'
# Error processing file meta_2024-02-17_17-21-16_RZ038.json: 'session_config'
# Error processing file meta_2024-03-14_12-28-25_RZ039.json: 'session_config'
# Error processing file meta_2024-03-19_12-34-45_RZ039.json: 'session_config'
# Error processing file meta_2024-03-12_12-36-28_RZ039.json: 'session_config'
# Error processing file meta_2024-03-28_10-56-11_RZ037.json: 'session_config'
# Error processing file meta_2024-03-16_11-49-38_RZ036.json: 'session_config'
# Error processing file meta_2024-04-12_10-22-23_RZ034.json: 'session_config'
# Error processing file meta_2024-03-29_10-21-17_RZ036.json: 'session_config'
# Error processing file meta_2024-02-15_11-12-28_RZ036.json: 'session_config'
# Error processing file meta_2024-03-11_12-44-42_RZ038.json: 'session_config'
# Error processing file meta_2024-02-14_10-16-51_RZ036.json: 'session_config'
# Error processing file meta_2024-01-30_09-55-23_RZ036.json: 'session_config'
# Error processing file meta_2024-03-04_12-27-13_RZ036.json: 'session_config'
# Error processing file meta_2024-03-07_11-16-04_RZ037.json: 'session_config'
# Error processing file meta_2024-03-23_11-32-23_RZ034.json: 'session_config'
# Error processing file meta_2024-03-07_12-39-24_RZ039.json: 'session_config'
# Error processing file meta_2024-02-14_11-54-43_RZ039.json: 'session_config'
# Error processing file meta_2024-02-11_14-46-34_RZ038.json: 'session_config'
# Error processing file meta_2024-03-11_12-43-41_RZ037.json: 'session_config'
# Error processing file meta_2024-01-23_11-21-27_RZ037.json: 'session_config'
# Error processing file meta_2024-02-14_11-00-26_RZ037.json: 'session_config'
# Error processing file meta_2024-04-02_11-20-32_RZ036.json: 'session_config'
# Error processing file meta_2024-02-09_10-36-47_RZ036.json: 'session_config'
# Error processing file meta_2024-03-16_11-47-24_RZ034.json: 'session_config'
# Error processing file meta_2024-03-22_12-46-45_RZ039.json: 'session_config'
# Error processing file meta_2024-03-29_11-15-40_RZ037.json: 'session_config'
# Error processing file meta_2024-01-23_10-36-35_RZ036.json: 'session_config'
# Error processing file meta_2024-01-23_10-46-58_RZ034.json: 'session_config'
# Error processing file meta_2024-03-26_11-34-49_RZ037.json: 'session_config'
# Error processing file meta_2024-03-05_12-22-43_RZ039.json: 'session_config'
# Error processing file meta_2024-03-28_10-18-36_RZ036.json: 'session_config'
# Error processing file meta_2024-03-19_10-18-47_RZ036.json: 'session_config'
# Error processing file meta_2024-02-21_13-33-05_RZ039.json: 'session_config'
# Error processing file meta_2024-03-07_10-25-31_RZ036.json: 'session_config'
# Error processing file meta_2024-04-02_11-03-45_RZ034.json: 'session_config'
# Error processing file meta_2024-03-11_11-53-45_RZ036.json: 'session_config'
# Error processing file meta_2024-02-08_10-14-34_RZ034.json: 'session_config'
# Error processing file meta_2024-02-12_13-11-48_RZ039.json: 'session_config'
# Error processing file meta_2024-04-15_12-43-20_RZ036.json: 'session_config'
# Error processing file meta_2024-04-05_12-12-32_RZ038.json: 'session_config'
# Error processing file meta_2024-02-20_11-10-14_RZ036.json: 'session_config'
# Error processing file meta_2024-02-12_11-50-27_RZ034.json: 'session_config'
# Error processing file meta_2024-03-28_10-19-24_RZ034.json: 'session_config'
# Error processing file meta_2024-02-16_10-18-04_RZ036.json: 'session_config'
# Error processing file meta_2024-02-15_11-10-31_RZ034.json: 'session_config'
# Error processing file meta_2024-03-20_12-19-27_RZ039.json: 'session_config'
# Error processing file meta_2024-03-29_12-31-18_RZ039.json: 'session_config'
# Error processing file meta_2024-01-31_12-45-11_RZ039.json: 'session_config'
# Error processing file meta_2024-03-21_11-06-09_RZ038.json: 'session_config'
# Error processing file meta_2024-04-03_16-37-44_RZ039.json: 'session_config'
# Error processing file meta_2024-01-26_11-21-04_RZ037.json: 'session_config'
# Error processing file meta_2024-02-29_12-16-47_RZ034.json: 'session_config'
# Error processing file meta_2024-03-06_13-46-04_RZ039.json: 'session_config'
# Error processing file meta_2024-04-09_13-25-21_RZ034.json: 'session_config'
# Error processing file meta_2024-04-15_13-23-53_RZ037.json: 'session_config'
# Error processing file meta_2024-02-13_12-31-30_RZ039.json: 'session_config'
# Error processing file meta_2024-01-26_10-17-27_RZ036.json: 'session_config'
# Error processing file meta_2024-04-10_11-42-25_RZ038.json: 'session_config'
# Error processing file meta_2024-02-09_10-35-01_RZ034.json: 'session_config'
# Error processing file meta_2024-01-25_10-53-33_RZ034.json: 'session_config'
# Error processing file meta_2024-03-25_13-34-24_RZ038.json: 'session_config'
# Error processing file meta_2024-02-16_10-59-28_RZ037.json: 'session_config'
# Error processing file meta_2024-02-08_16-00-16_RZ039.json: 'session_config'
# Error processing file meta_2024-03-05_11-11-27_RZ037.json: 'session_config'
# Error processing file meta_2024-03-05_11-14-12_RZ038.json: 'session_config'
# Error processing file meta_2024-02-28_11-09-43_RZ037.json: 'session_config'
# Error processing file meta_2024-03-15_11-04-32_RZ037.json: 'session_config'
# Error processing file meta_2024-03-04_13-15-40_RZ037.json: 'session_config'
# Error processing file meta_2024-02-11_14-03-26_RZ034.json: 'session_config'
# Error processing file meta_2024-02-11_14-33-01_RZ037.json: 'session_config'
# Error processing file meta_2024-02-16_11-00-02_RZ038.json: 'session_config'
# Error processing file meta_2024-02-17_17-17-25_RZ037.json: 'session_config'
# Error processing file meta_2024-03-06_12-32-44_RZ037.json: 'session_config'
# Error processing file meta_2024-02-19_13-15-25_RZ039.json: 'session_config'
# Error processing file meta_2024-02-01_11-19-24_RZ034.json: 'session_config'
# Error processing file meta_2024-03-14_10-18-34_RZ034.json: 'session_config'
# Error processing file meta_2024-03-28_12-26-22_RZ039.json: 'session_config'
# Error processing file meta_2024-02-27_10-10-40_RZ036.json: 'session_config'
# Error processing file meta_2024-01-24_10-12-40_RZ034.json: 'session_config'
# Error processing file meta_2024-01-30_11-40-20_RZ039.json: 'session_config'
# Error processing file meta_2024-04-09_09-23-29_RZ037.json: 'session_config'
# Error processing file meta_2024-04-09_13-46-24_RZ036.json: 'session_config'
# Error processing file meta_2024-03-26_11-35-34_RZ038.json: 'session_config'
# Error processing file meta_2024-03-01_10-17-44_RZ034.json: 'session_config'
# Error processing file meta_2024-02-08_11-04-34_RZ038.json: 'session_config'
# Error processing file meta_2024-03-03_14-16-22_RZ037.json: 'session_config'
# Error processing file meta_2024-02-02_12-11-47_RZ039.json: 'session_config'
# Error processing file meta_2024-02-13_11-22-27_RZ037.json: 'session_config'
# Error processing file meta_2024-03-20_10-58-44_RZ038.json: 'session_config'
# Error processing file meta_2024-02-05_10-58-37_RZ036.json: 'session_config'
# Error processing file meta_2024-04-10_12-32-27_RZ039.json: 'session_config'
# Error processing file meta_2024-02-15_11-56-13_RZ037.json: 'session_config'
# Error processing file meta_2024-03-14_10-20-05_RZ036.json: 'session_config'
# Error processing file meta_2024-03-06_11-41-07_RZ034.json: 'session_config'
# Error processing file meta_2024-02-14_10-15-11_RZ034.json: 'session_config'
# Error processing file meta_2024-03-18_12-25-39_RZ037.json: 'session_config'
# Error processing file meta_2024-03-06_12-37-29_RZ038.json: 'session_config'
# Error processing file meta_2024-04-15_13-39-14_RZ038.json: 'session_config'
# Error processing file meta_2024-03-03_13-38-43_RZ034.json: 'session_config'
# Error processing file meta_2024-01-29_14-06-51_RZ039.json: 'session_config'
# Error processing file meta_2024-04-04_10-03-18_RZ036.json: 'session_config'
# Error processing file meta_2024-03-05_10-21-34_RZ034.json: 'session_config'
# Error processing file meta_2024-02-21_12-27-24_RZ037.json: 'session_config'
# Error processing file meta_2024-03-12_10-31-04_RZ036.json: 'session_config'
# Error processing file meta_2024-03-23_12-26-27_RZ038.json: 'session_config'
# Error processing file meta_2024-03-12_10-28-46_RZ034.json: 'session_config'
# Error processing file meta_2024-03-14_11-07-47_RZ037.json: 'session_config'
# Error processing file meta_2024-04-10_11-35-05_RZ037.json: 'session_config'
# Error processing file meta_2024-02-17_16-49-50_RZ036.json: 'session_config'
# Error processing file meta_2024-04-04_11-31-10_RZ039.json: 'session_config'
# Error processing file meta_2024-01-25_12-00-37_RZ038.json: 'session_config'
# Error processing file meta_2024-02-17_16-46-32_RZ034.json: 'session_config'
# Error processing file meta_2024-02-16_10-17-06_RZ034.json: 'session_config'
# Error processing file meta_2024-02-19_12-29-40_RZ038.json: 'session_config'
# Error processing file meta_2024-03-26_12-37-05_RZ039.json: 'session_config'
# Error processing file meta_2024-01-23_12-25-16_RZ039.json: 'session_config'
# Error processing file meta_2024-03-15_10-15-49_RZ034.json: 'session_config'
# Error processing file meta_2024-02-03_16-32-53_RZ039.json: 'session_config'
# Error processing file meta_2024-02-21_11-49-19_RZ034.json: 'session_config'
# Error processing file meta_2024-01-29_12-15-36_RZ034.json: 'session_config'
# Error processing file meta_2024-02-20_11-54-10_RZ038.json: 'session_config'
# Error processing file meta_2024-03-27_10-20-58_RZ034.json: 'session_config'
# Error processing file meta_2024-01-31_11-42-34_RZ037.json: 'session_config'
# Error processing file meta_2024-03-14_11-08-37_RZ038.json: 'session_config'
# Error processing file meta_2024-04-03_11-20-08_RZ037.json: 'session_config'
# Error processing file meta_2024-02-07_11-35-38_RZ036.json: 'session_config'
# Error processing file meta_2024-01-24_11-13-21_RZ038.json: 'session_config'
# Error processing file meta_2024-02-29_14-23-57_RZ039.json: 'session_config'
# Error processing file meta_2024-02-22_11-10-00_RZ034.json: 'session_config'
# Error processing file meta_2024-02-03_14-57-59_RZ036.json: 'session_config'
# Error processing file meta_2024-03-20_10-09-05_RZ036.json: 'session_config'
# Error processing file meta_2024-02-02_10-34-46_RZ036.json: 'session_config'
# Error processing file meta_2024-03-27_11-04-29_RZ037.json: 'session_config'
# Error processing file meta_2024-04-01_14-06-34_RZ039.json: 'session_config'
# Error processing file meta_2024-04-11_11-10-33_RZ037.json: 'session_config'
# Error processing file meta_2024-02-12_12-19-00_RZ037.json: 'session_config'
# Error processing file meta_2024-03-18_12-28-57_RZ038.json: 'session_config'
# Error processing file meta_2024-02-16_11-49-35_RZ039.json: 'session_config'
# Error processing file meta_2024-04-03_10-36-22_RZ034.json: 'session_config'
# Error processing file meta_2024-02-03_15-46-55_RZ038.json: 'session_config'
# Error processing file meta_2024-01-24_11-04-30_RZ037.json: 'session_config'
# Error processing file meta_2024-03-22_10-45-01_RZ034.json: 'session_config'
# Error processing file meta_2024-02-12_12-24-51_RZ038.json: 'session_config'
# Error processing file meta_2024-02-26_13-10-15_RZ038.json: 'session_config'
# Error processing file meta_2024-04-02_13-17-59_RZ039.json: 'session_config'
# Error processing file meta_2024-03-25_14-07-25_RZ039.json: 'session_config'
# Error processing file meta_2024-02-15_13-12-32_RZ039.json: 'session_config'
# Error processing file meta_2024-02-17_18-06-57_RZ039.json: 'session_config'
# Error processing file meta_2024-03-05_10-24-20_RZ036.json: 'session_config'
# Error processing file meta_2024-03-21_10-15-38_RZ036.json: 'session_config'
# Error processing file meta_2024-02-07_12-42-31_RZ039.json: 'session_config'
# Error processing file meta_2024-02-22_11-11-05_RZ036.json: 'session_config'
# Error processing file meta_2024-04-03_10-37-53_RZ036.json: 'session_config'
# Error processing file meta_2024-03-22_11-40-32_RZ038.json: 'session_config'
# Error processing file meta_2024-03-20_10-57-46_RZ037.json: 'session_config'
# Error processing file meta_2024-03-03_14-19-20_RZ038.json: 'session_config'
# Error processing file meta_2024-04-15_12-42-19_RZ034.json: 'session_config'
# Error processing file meta_2024-04-04_10-02-20_RZ034.json: 'session_config'
# Error processing file meta_2024-03-15_10-16-39_RZ036.json: 'session_config'
# Error processing file meta_2024-03-19_10-17-28_RZ034.json: 'session_config'
# Error processing file meta_2024-04-12_11-14-07_RZ038.json: 'session_config'
# Error processing file meta_2024-04-11_10-28-39_RZ036.json: 'session_config'
# Error processing file meta_2024-03-15_11-10-33_RZ038.json: 'session_config'
# Error processing file meta_2024-02-26_12-12-13_RZ036.json: 'session_config'
# Error processing file meta_2024-02-23_11-31-40_RZ034.json: 'session_config'
# Error processing file meta_2024-01-25_13-01-51_RZ039.json: 'session_config'
# Error processing file meta_2024-02-23_13-43-31_RZ039.json: 'session_config'
# Error processing file meta_2024-02-01_11-21-19_RZ036.json: 'session_config'
# Error processing file meta_2024-02-08_11-03-26_RZ037.json: 'session_config'
# Error processing file meta_2024-03-22_10-46-18_RZ036.json: 'session_config'
# Error processing file meta_2024-02-08_10-15-55_RZ036.json: 'session_config'
# Error processing file meta_2024-02-29_13-01-34_RZ037.json: 'session_config'
# Error processing file meta_2024-03-21_11-58-04_RZ039.json: 'session_config'
# Error processing file meta_2024-02-02_15-44-43_RZ037.json: 'session_config'
# Error processing file meta_2024-01-26_11-22-00_RZ038.json: 'session_config'
# Error processing file meta_2024-03-28_13-58-11_RZ039.json: 'session_config'
# Error processing file meta_2024-03-25_12-18-30_RZ036.json: 'session_config'
# Error processing file meta_2024-02-19_11-42-21_RZ034.json: 'session_config'
# Error processing file meta_2024-02-29_13-05-18_RZ038.json: 'session_config'
# Error processing file meta_2024-04-09_09-27-10_RZ038.json: 'session_config'
# Error processing file meta_2024-02-07_11-07-18_RZ034.json: 'session_config'
# Error processing file meta_2024-03-23_13-03-07_RZ039.json: 'session_config'
# Error processing file meta_2024-02-27_10-09-17_RZ034.json: 'session_config'
# Error processing file meta_2024-03-12_11-16-51_RZ038.json: 'session_config'
# Error processing file meta_2024-02-20_12-59-01_RZ039.json: 'session_config'
# Error processing file meta_2024-03-04_14-27-00_RZ039.json: 'session_config'
# Error processing file meta_2024-03-23_11-33-38_RZ036.json: 'session_config'
# Error processing file meta_2024-04-05_11-20-32_RZ034.json: 'session_config'
# Error processing file meta_2024-04-01_11-51-57_RZ034.json: 'session_config'
# Error processing file meta_2024-03-16_12-21-41_RZ037.json: 'session_config'
# Error processing file meta_2024-03-11_11-52-45_RZ034.json: 'session_config'
# Error processing file meta_2024-02-27_10-55-50_RZ037.json: 'session_config'
# Error processing file meta_2024-01-31_11-45-20_RZ038.json: 'session_config'
# Error processing file meta_2024-03-16_12-22-55_RZ038.json: 'session_config'
# Error processing file meta_2024-02-14_11-03-43_RZ038.json: 'session_config'
# Error processing file meta_2024-02-28_10-19-48_RZ034.json: 'session_config'
# Error processing file meta_2024-03-01_10-18-52_RZ036.json: 'session_config'
# Error processing file meta_2024-02-21_11-50-53_RZ036.json: 'session_config'
# Error processing file meta_2024-02-09_11-32-50_RZ037.json: 'session_config'
# Error processing file meta_2024-01-29_13-24-16_RZ037.json: 'session_config'
# Error processing file meta_2024-02-05_10-57-40_RZ034.json: 'session_config'
# Error processing file meta_2024-03-19_11-34-35_RZ038.json: 'session_config'
# Error processing file meta_2024-02-23_12-10-00_RZ037.json: 'session_config'
# Error processing file meta_2024-01-23_11-31-57_RZ038.json: 'session_config'
# Error processing file meta_2024-04-08_12-24-38_RZ034.json: 'session_config'
# Error processing file meta_2024-02-11_15-45-02_RZ039.json: 'session_config'
# Error processing file meta_2024-04-01_11-53-16_RZ036.json: 'session_config'
# Error processing file meta_2024-03-26_10-43-44_RZ034.json: 'session_config'
# Error processing file meta_2024-02-28_10-21-01_RZ036.json: 'session_config'
# Error processing file meta_2024-02-01_12-24-53_RZ038.json: 'session_config'
# Error processing file meta_2024-02-28_12-07-40_RZ039.json: 'session_config'
# Error processing file meta_2024-03-25_13-33-12_RZ037.json: 'session_config'
# Error processing file meta_2024-03-18_13-04-52_RZ039.json: 'session_config'
# Error processing file meta_2024-02-19_11-43-55_RZ036.json: 'session_config'
# Error processing file meta_2024-01-25_10-54-55_RZ036.json: 'session_config'
# Error processing file meta_2024-04-05_13-16-39_RZ039.json: 'session_config'
# Error processing file meta_2024-04-12_11-09-19_RZ037.json: 'session_config'
# Error processing file meta_2024-03-23_12-18-15_RZ037.json: 'session_config'
# Error processing file meta_2024-03-06_11-42-35_RZ036.json: 'session_config'
# Error processing file meta_2024-02-22_12-47-11_RZ039.json: 'session_config'
# Error processing file meta_2024-02-26_13-09-03_RZ037.json: 'session_config'
# Error processing file meta_2024-04-11_10-27-39_RZ034.json: 'session_config'
# Error processing file meta_2024-04-11_12-09-41_RZ039.json: 'session_config'
# Error processing file meta_2024-02-03_14-56-53_RZ034.json: 'session_config'
# Error processing file meta_2024-01-31_10-37-51_RZ034.json: 'session_config'
# Error processing file meta_2024-02-26_12-10-55_RZ034.json: 'session_config'
# Error processing file meta_2024-03-07_11-23-56_RZ038.json: 'session_config'
# Error processing file meta_2024-03-11_14-05-44_RZ039.json: 'session_config'
# Error processing file meta_2024-01-26_12-28-26_RZ039.json: 'session_config'
# Error processing file meta_2024-01-24_12-07-22_RZ039.json: 'session_config'
# Error processing file meta_2024-03-29_10-20-14_RZ034.json: 'session_config'
# Error processing file meta_2024-03-22_11-38-58_RZ037.json: 'session_config'
# Error processing file meta_2024-02-22_12-05-08_RZ038.json: 'session_config'
# Error processing file meta_2024-03-03_13-42-38_RZ036.json: 'session_config'
# Error processing file meta_2024-02-20_11-08-43_RZ034.json: 'session_config'
# Error processing file meta_2024-02-09_11-34-31_RZ038.json: 'session_config'
# Error processing file meta_2024-04-02_11-48-35_RZ037.json: 'session_config'
# Error processing file meta_2024-01-26_10-16-01_RZ034.json: 'session_config'
# Error processing file meta_2024-04-09_10-12-54_RZ039.json: 'session_config'
# Error processing file meta_2024-03-28_11-10-07_RZ038.json: 'session_config'
# Error processing file meta_2024-02-03_15-45-42_RZ037.json: 'session_config'
# Error processing file meta_2024-04-01_12-49-49_RZ038.json: 'session_config'
# Error processing file meta_2024-02-11_14-04-42_RZ036.json: 'session_config'
# Error processing file meta_2024-02-13_11-24-53_RZ038.json: 'session_config'
# Error processing file meta_2024-02-07_12-24-31_RZ038.json: 'session_config'
# Error processing file meta_2024-04-11_11-23-37_RZ038.json: 'session_config'
# Error processing file meta_2024-02-27_11-55-58_RZ039.json: 'session_config'
# Error processing file meta_2024-03-01_11-15-25_RZ037.json: 'session_config'
# Error processing file meta_2024-02-22_11-49-40_RZ037.json: 'session_config'
# Error processing file meta_2024-04-08_12-25-55_RZ036.json: 'session_config'
# Error processing file meta_2024-02-15_11-58-57_RZ038.json: 'session_config'
# Error processing file meta_2024-02-20_11-53-03_RZ037.json: 'session_config'
# Error processing file meta_2024-01-29_12-16-45_RZ036.json: 'session_config'
# Error processing file meta_2024-03-21_11-05-13_RZ037.json: 'session_config'
# Error processing file meta_2024-03-26_10-45-11_RZ036.json: 'session_config'
# Error processing file meta_2024-02-28_11-12-28_RZ038.json: 'session_config'
# Error processing file meta_2024-04-10_10-44-57_RZ034.json: 'session_config'
# Error processing file meta_2024-04-04_10-47-12_RZ037.json: 'session_config'
# Error processing file meta_2024-03-27_10-21-58_RZ036.json: 'session_config'
# Error processing file meta_2024-02-05_11-46-46_RZ037.json: 'session_config'
# Error processing file meta_2024-02-13_10-24-30_RZ034.json: 'session_config'
# Error processing file meta_2024-02-19_12-24-10_RZ037.json: 'session_config'
# Error processing file meta_2024-03-29_11-40-12_RZ038.json: 'session_config'
# Error processing file meta_2024-02-27_10-57-47_RZ038.json: 'session_config'
# Error processing file meta_2024-04-10_10-46-09_RZ036.json: 'session_config'
# Error processing file meta_2024-03-03_15-01-24_RZ039.json: 'session_config'
# Error processing file meta_2024-02-13_10-26-12_RZ036.json: 'session_config'
# Error processing file meta_2024-03-01_12-37-22_RZ039.json: 'session_config'
# Error processing file meta_2024-02-05_14-16-34_RZ039.json: 'session_config'
# Error processing file meta_2024-02-21_12-45-19_RZ038.json: 'session_config'
# Error processing file meta_2024-04-04_10-50-12_RZ038.json: 'session_config'
# Error processing file meta_2024-02-29_12-18-09_RZ036.json: 'session_config'
# Error processing file meta_2024-01-29_13-25-50_RZ038.json: 'session_config'
# Error processing file meta_2024-03-18_11-34-04_RZ034.json: 'session_config'
# Error processing file meta_2024-03-16_13-01-46_RZ039.json: 'session_config'
# Error processing file meta_2024-03-04_12-24-58_RZ034.json: 'session_config'
# Error processing file meta_2024-03-27_12-09-08_RZ039.json: 'session_config'
# Error processing file meta_2024-04-15_14-48-29_RZ039.json: 'session_config'
# Error processing file meta_2024-01-30_10-36-04_RZ037.json: 'session_config'
# Error processing file meta_2024-01-25_11-59-05_RZ037.json: 'session_config'
# Error processing file meta_2024-02-05_11-47-44_RZ038.json: 'session_config'
# Error processing file meta_2024-03-07_10-24-29_RZ034.json: 'session_config'
# Error processing file meta_2024-03-01_11-27-47_RZ038.json: 'session_config'
# Error processing file meta_2024-04-03_11-21-25_RZ038.json: 'session_config'
# Error processing file meta_2024-03-18_11-35-53_RZ036.json: 'session_config'
# Error processing file meta_2024-02-01_12-08-02_RZ037.json: 'session_config'
# Error processing file meta_2024-01-31_10-39-08_RZ036.json: 'session_config'
# Error processing file meta_2024-03-15_12-31-59_RZ039.json: 'session_config'
# Error processing file meta_2024-02-23_11-32-47_RZ036.json: 'session_config'
# Error processing file meta_2024-02-26_14-05-28_RZ039.json: 'session_config'
# Error processing file meta_2024-03-12_11-05-26_RZ037.json: 'session_config'
# Error processing file meta_2024-04-12_12-19-19_RZ039.json: 'session_config'
#      index        date      time  mouse exp training   rig  trainer  record  \
# 0      197  2024-05-03  12-04-42  RZ036   2  regular  rig3  Rebekah   False
# 1      108  2024-05-03  12-05-32  RZ034   2  regular  rig2  Rebekah   False
# 2      143  2024-05-03  12-47-24  RZ037   2  regular  rig3  Rebekah   False
# 3      165  2024-05-03  12-59-12  RZ038   2  regular  rig2  Rebekah   False
# 4       30  2024-05-03  14-16-43  RZ039   2  regular  rig3  Rebekah   False
# ..     ...         ...       ...    ...  ..      ...   ...      ...     ...
# 210      0  2024-07-18  15-07-36  RZ038   2  regular  rig1  Rebekah    True
# 211    210  2024-07-18  17-22-52  RZ039   2  regular  rig1  Rebekah    True
# 212    133  2024-07-19  11-50-39  RZ037   2  regular  rig1  Rebekah    True
# 213    208  2024-07-19  12-38-14  RZ038   2  regular  rig1  Rebekah    True
# 214    155  2024-07-19  14-36-21  RZ039   2  regular  rig1  Rebekah    True
#
#      total_reward  total_trial  avg_tw ending_code                        dir  \
# 0             700          389    1.36      reward  2024-05-03_12-04-42_RZ036
# 1             700          508    1.28      reward  2024-05-03_12-05-32_RZ034
# 2             700          437    1.92      reward  2024-05-03_12-47-24_RZ037
# 3             630          233   11.40        miss  2024-05-03_12-59-12_RZ038
# 4             700          344    2.68      reward  2024-05-03_14-16-43_RZ039
# ..            ...          ...     ...         ...                        ...
# 210           625          201    6.60        miss  2024-07-18_15-07-36_RZ038
# 211           900          401    3.01      reward  2024-07-18_17-22-52_RZ039
# 212           340          101    8.24      pygame  2024-07-19_11-50-39_RZ037
# 213           505          176    9.30        miss  2024-07-19_12-38-14_RZ038
# 214           630          232    4.61        miss  2024-07-19_14-36-21_RZ039
#
#     group  session
# 0       s        0
# 1       s        0
# 2       l        0
# 3       l        0
# 4       l        0
# ..    ...      ...
# 210     l       43
# 211     l       39
# 212     l       42
# 213     l       44
# 214     l       40
#
# [215 rows x 16 columns]

# %% [markdown]
# ## Quality control
# doesn't need to run when data folder is cleaned
# <br>
# sessions_all needs to be regenerated after every cleaning step, so run the step above

# %% [markdown]
# ### Remove test sessions

# %%
def remove_sessions(sessions_to_remove, data_folder):
    for _, session_info in sessions_to_remove.iterrows():
        shutil.rmtree(os.path.join(data_folder, session_info.dir))

# %%
sessions_test = sessions_all.loc[sessions_all.mouse=='test']
if len(sessions_test) > 0:
    remove_sessions(sessions_test, data_folder)
    print("test sessions removed")
else:
    print("no test sessions to be delted!")
# Out:
# no test sessions to be delted!

# %% [markdown]
# ### Check for short sessions

# %%
short_threshold = 30

# %%
sessions_short = sessions_all[(sessions_all['total_trial'] < short_threshold) | sessions_all['total_trial'].isna()]
if len(sessions_short)>0:
    display(sessions_short)
else: 
    print('no short sessions to be checked!')
# Out:
# no short sessions to be checked!

# %% [markdown]
# remove short sessions if needed

# %%
remove_sessions(sessions_short, data_folder)

# %% [markdown]
# # Process events

# %% [markdown]
# load session log

# %%
sessions_training = utils.load_data(os.path.join(data_folder, 'sessions_training.csv'))

# %%
# trim events to based on ending code
def process_events(session_info, events):
    ending_to_adjust = ['pygame', 'miss']
    ending_smooth = ['time', 'reward', 'trial']
    if session_info['ending_code'] in ending_to_adjust:
        events = events.loc[events['session_trial_num'].between(0, session_info['total_trial'])]
    elif session_info['ending_code'] in ending_smooth:
        events = events.iloc[2:-1]
    else:
        print(session_info['dir'])
        raise "ending code unknown"
    return events

# %%
problematic_sessions = pd.DataFrame(columns=sessions_training.columns)

for _, session_info in sessions_training.iterrows():
    try:
        events_processed_path = utils.generate_events_processed_path(data_folder, session_info)
        if os.path.isfile(events_processed_path):
            continue
        events = pd.read_csv(utils.generate_events_path(data_folder, session_info), low_memory=False)
        events = process_events(session_info, events)
        events_processed = events.groupby('session_trial_num', group_keys=False).apply(helper.add_trial_time)
        events_processed.to_csv(events_processed_path)
    except:
        problematic_sessions = pd.concat([problematic_sessions, session_info.to_frame().T], ignore_index=True)

# %%
if len(problematic_sessions) > 0:
    display(problematic_sessions)
else:
    print("all sessions are perfect! woohoo!")
# Out:
# all sessions are perfect! woohoo!

# %% [markdown]
# !!! can use move dir to new folder function to do for problematic sections !!!

# %% [markdown]
# # Generate trials

# %%
def get_trial_basics(trial):
    """gets the df of a trial, extracts 5 things, and outputs as a dictionary"""
    trial_start = trial.loc[(trial['key'] == 'trial') & (trial['value'] == 1)].iloc[0]
    trial_end = trial.loc[(trial['key'] == 'trial') & (trial['value'] == 0)].iloc[0]

    trial_basics = {'session_trial_num': trial_start['session_trial_num'],
                    'block_trial_num': trial_start['block_trial_num'],
                    'block_num': trial_start['block_num'],
                    'start_time': trial_start['session_time'],
                    'end_time': trial_end['session_time']}
    return trial_basics

# %%
def generate_trials(session_info, events):
    trial_info_list = []
    for t in range(int(session_info.total_trial)):
        trial = events.loc[events['session_trial_num'] == t]
        trial_basics = get_trial_basics(trial)
        trial_info_list.append(trial_basics)
    trials = pd.DataFrame(trial_info_list)
    return trials

# %%
# generate all trials based on events processed
problematic_sessions = pd.DataFrame(columns=sessions_training.columns)
for _, session_info in sessions_training.iterrows():
    try: 
        trials_path = utils.generate_trials_path(data_folder, session_info)
        if os.path.isfile(trials_path):
            continue
        
        events_processed = pd.read_csv(utils.generate_events_processed_path(data_folder, session_info))
        trials = generate_trials(session_info, events_processed)

        trials.to_csv(trials_path)
    except:
        problematic_sessions = pd.concat([problematic_sessions, session_info.to_frame().T], ignore_index=True)

# %%
if len(problematic_sessions) > 0:
    display(problematic_sessions)
else:
    print("all sessions are perfect! woohoo!")
# Out:
# all sessions are perfect! woohoo!

# %% [markdown]
# ## Analyze trials

# %%
for _, session_info in sessions_training.iterrows():
    trials_analyzed_path = utils.generate_trials_analyzed_path(data_folder, session_info)
    if os.path.isfile(trials_analyzed_path):
        continue
    
    session_by_trial = utils.load_data(utils.generate_events_processed_path(data_folder, session_info)).groupby('session_trial_num')
    trials = utils.load_data(utils.generate_trials_path(data_folder, session_info))
    trials_data = helper.get_trial_data_df(session_by_trial)
    trials_analyzed = pd.merge(trials, trials_data, on='session_trial_num')
    trials_analyzed['group'] = session_info.group #assigning trial type manually
    trials_analyzed.to_csv(trials_analyzed_path)
