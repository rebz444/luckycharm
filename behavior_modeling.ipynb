# %%
import os

import utils

import pandas as pd

# %%
data_dir = '/Users/rebekahzhang/data/behavior_data'
exp = "exp2"
data_folder = os.path.join(data_dir, exp)
model_folder = os.path.join(data_dir, f'{exp}_model')
os.makedirs(model_folder, exist_ok=True)

print(data_folder)
print(model_folder)
# Out:
# /Users/rebekahzhang/data/behavior_data/exp2
# /Users/rebekahzhang/data/behavior_data/exp2_model

# %%
sessions_training = utils.load_session_log(data_folder, f'sessions_training_{exp}.csv')
print(f'{len(sessions_training)} sessions')
trials_training = utils.load_data(os.path.join(data_folder, 'trials_training_analyzed.csv'))
print(f'{len(trials_training)} trials')
# Out:
# 1852 sessions
# 652754 trials

# %%
sessions_training.keys()
# Out:
# Index(['date', 'time', 'mouse', 'exp', 'training', 'rig', 'avg_tw',
#        'ending_code', 'dir', 'cohort', 'version', 'num_blocks', 'num_trials',
#        'rewards', 'session_time', 'group', 'session'],
#       dtype='object')

# %%
sessions_training.session_time.sum()
# Out:
# 7451517.1
